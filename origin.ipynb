# %%
import pandas as pd

# %%
df = pd.read_csv(r"E:\EXcellenC\Projects\Project two\CAR_DATANEW.csv")
df
# Out:
#          City                                          Car Name         Price  \
# 0      Mumbai               2013 Mercedes-Benz G-Class G 63 AMG     ₹ 88 Lakh
# 1      Mumbai                        2021 Tata Nexon EV XZ Plus   ₹ 9.25 Lakh
# 2      Mumbai                           2023 MG ZS EV Exclusive  ₹ 18.45 Lakh
# 3      Mumbai       2020 Mercedes-Benz E-Class E 220d Exclusive  ₹ 41.75 Lakh
# 4      Mumbai  2022 Mercedes-Benz AMG GLA 35 4MATIC [2021-2023]  ₹ 49.99 Lakh
# ...       ...                                               ...           ...
# 10071  Almora          2022 Tata Nexon XZ Plus (O) Dark Edition    ₹ 9.5 Lakh
# 10072  Almora               2018 Maruti Suzuki Baleno Delta 1.3    ₹ 6.5 Lakh
# 10073  Almora                       2019 Honda WR-V S MT Petrol    ₹ 6.1 Lakh
# 10074  Almora          2023 Hyundai Exter SX (O) Connect 1.2 MT      ₹ 8 Lakh
# 10075  Almora              2024 Skoda Kushaq Style 1.5L TSI DSG     ₹ 19 Lakh
#
# ...

# %%
df["brand"].unique()
# Out:
# array(['Mercedes-Benz G-Class', 'Tata', 'MG', 'Mercedes-Benz E-Class',
#        'Mercedes-Benz AMG', 'Skoda', 'Jaguar', 'Maruti', 'Hyundai', 'Kia',
#        'Jeep', 'Toyota', 'Mahindra', 'Renault', 'Ford',
#        'Mercedes-Benz GLA', 'BMW', 'Volkswagen', 'Honda',
#        'Mercedes-Benz GLC', 'Mercedes-Benz C-Class',
#        'Mercedes-Benz V-Class', 'Land Rover', 'Audi', 'Mercedes-Benz GLE',
#        'Lexus', 'Mercedes-Benz CLA', 'MINI', 'Mercedes-Benz S-Class',
#        'Volvo', 'Porsche', 'Rolls-Royce Phantom', 'Bentley',
#        'Mercedes-Benz M-Class', 'Mercedes-Benz GLS', 'Mercedes-Benz EQB',
#        'Nissan', 'Hindustan', 'Chevrolet', 'Datsun', 'Fiat', 'Ashok',
#        'Mercedes-Benz A-Class', 'Force', 'BYD', 'Mercedes-Benz GL-Class',
#        'Mercedes-Benz B-class', 'Mercedes-Benz EQS', 'Mercedes-Benz EQC',
#        'Mercedes-Benz CLS', 'Isuzu', 'Mercedes-Benz EQE', 'Mitsubishi',
#        'Mercedes-Benz EQA', 'Mercedes-Benz Maybach', 'Maserati',
# ...

# %%
# Dictionary mapping brands to origins
brand_origin_map = {
    # German
    'Mercedes-Benz G-Class': 'German',
    'Mercedes-Benz E-Class': 'German',
    'Mercedes-Benz AMG': 'German',
    'Mercedes-Benz GLA': 'German',
    'Mercedes-Benz GLC': 'German',
    'Mercedes-Benz C-Class': 'German',
    'Mercedes-Benz V-Class': 'German',
    'Mercedes-Benz GLE': 'German',
    'Mercedes-Benz CLA': 'German',
    'Mercedes-Benz S-Class': 'German',
    'Mercedes-Benz M-Class': 'German',
    'Mercedes-Benz GLS': 'German',
    'Mercedes-Benz EQB': 'German',
    'Mercedes-Benz A-Class': 'German',
    'Mercedes-Benz GL-Class': 'German',
    'Mercedes-Benz B-class': 'German',
    'Mercedes-Benz EQS': 'German',
    'Mercedes-Benz EQC': 'German',
    'Mercedes-Benz CLS': 'German',
    'Mercedes-Benz EQE': 'German',
    'Mercedes-Benz EQA': 'German',
    'Mercedes-Benz Maybach': 'German',
    'Mercedes-Benz W110': 'German',
    'Mercedes-Benz SLK-Class': 'German',
    'BMW': 'German',
    'Audi': 'German',
    'Volkswagen': 'German',
    'Porsche': 'German',
    'MINI': 'German',
    'Skoda': 'German',

    # Japanese
    'Toyota': 'Japanese',
    'Honda': 'Japanese',
    'Nissan': 'Japanese',
    'Mitsubishi': 'Japanese',
    'Lexus': 'Japanese',
    'Datsun': 'Japanese',
    'Isuzu': 'Japanese',

    # Korean
    'Hyundai': 'Korean',
    'Kia': 'Korean',
    'Ssangyong': 'Korean',

    # Indian
    'Tata': 'Indian',
    'Mahindra': 'Indian',
    'Maruti': 'Indian',
    'Hindustan': 'Indian',
    'Ashok': 'Indian',
    'Force': 'Indian',

    # American
    'Jeep': 'American',
    'Ford': 'American',
    'Chevrolet': 'American',
    'Hummer': 'American',

    # British
    'Jaguar': 'British',
    'Land Rover': 'British',
    'Rolls-Royce Phantom': 'British',
    'Rolls-Royce Ghost': 'British',
    'Bentley': 'British',
    'Aston': 'British',
    
    # French
    'Renault': 'French',
    'Citroen': 'French',

    # Italian
    'Maserati': 'Italian',
    'Ferrari': 'Italian',
    'Lamborghini': 'Italian',
    'Fiat': 'Italian',

    # Chinese
    'MG': 'Chinese',
    'BYD': 'Chinese',
    
    #Swedish
    'Volvo':'Swedish',
}

# Add a new column for origin based on the brand
df['origin'] = df['brand'].map(brand_origin_map)

# Optional: Fill missing values with 'Unknown'
df['origin'] = df['origin'].fillna('Unknown')

# %% [raw]
# df

# %%
df
# Out:
#          City                                          Car Name         Price  \
# 0      Mumbai               2013 Mercedes-Benz G-Class G 63 AMG     ₹ 88 Lakh
# 1      Mumbai                        2021 Tata Nexon EV XZ Plus   ₹ 9.25 Lakh
# 2      Mumbai                           2023 MG ZS EV Exclusive  ₹ 18.45 Lakh
# 3      Mumbai       2020 Mercedes-Benz E-Class E 220d Exclusive  ₹ 41.75 Lakh
# 4      Mumbai  2022 Mercedes-Benz AMG GLA 35 4MATIC [2021-2023]  ₹ 49.99 Lakh
# ...       ...                                               ...           ...
# 10071  Almora          2022 Tata Nexon XZ Plus (O) Dark Edition    ₹ 9.5 Lakh
# 10072  Almora               2018 Maruti Suzuki Baleno Delta 1.3    ₹ 6.5 Lakh
# 10073  Almora                       2019 Honda WR-V S MT Petrol    ₹ 6.1 Lakh
# 10074  Almora          2023 Hyundai Exter SX (O) Connect 1.2 MT      ₹ 8 Lakh
# 10075  Almora              2024 Skoda Kushaq Style 1.5L TSI DSG     ₹ 19 Lakh
#
# ...

# %%
df["origin"].unique()
# Out:
# array(['German', 'Indian', 'Chinese', 'British', 'Korean', 'American',
#        'Japanese', 'French', 'Swedish', 'Italian'], dtype=object)

# %%
df["origin"].value_counts()
# Out:
# origin
# Indian      3496
# German      2175
# Korean      1794
# Japanese    1395
# American     443
# French       295
# Chinese      211
# British      166
# Swedish       80
# Italian       21
# Name: count, dtype: int64

# %%
unknown_brands = df[df['origin'] == 'Unknown']['brand'].unique()
print(unknown_brands)
# Out:
# []

# %%
df.columns
# Out:
# Index(['City', 'Car Name', 'Price', 'Kilometers Driven', 'Transmission',
#        'Fuel Type', 'Manufacturing Year', 'Number of Owners', 'Color',
#        'Car Available At', 'Insurance', 'Registration', 'URL', 'brand',
#        'model', 'transmission_type', 'gears', 'manual_override',
#        'paddle_shift', 'sport_mode', 'origin'],
#       dtype='object')

# %%
df.columns = [col.capitalize() for col in df.columns]

# %%
df.columns = [col.title() for col in df.columns]

# %%
df.columns
# Out:
# Index(['City', 'Car Name', 'Price', 'Kilometers Driven', 'Transmission',
#        'Fuel Type', 'Manufacturing Year', 'Number Of Owners', 'Color',
#        'Car Available At', 'Insurance', 'Registration', 'Url', 'Brand',
#        'Model', 'Transmission_Type', 'Gears', 'Manual_Override',
#        'Paddle_Shift', 'Sport_Mode', 'Origin'],
#       dtype='object')

# %%
df.drop(columns=['Url'],inplace=True)

# %%
df.columns
# Out:
# Index(['City', 'Car Name', 'Price', 'Kilometers Driven', 'Transmission',
#        'Fuel Type', 'Manufacturing Year', 'Number Of Owners', 'Color',
#        'Car Available At', 'Insurance', 'Registration', 'Brand', 'Model',
#        'Transmission_Type', 'Gears', 'Manual_Override', 'Paddle_Shift',
#        'Sport_Mode', 'Origin'],
#       dtype='object')

# %%
df.to_csv(r"E:\EXcellenC\Projects\Project two\CAR_DATANEW_updated.csv", index=False)
